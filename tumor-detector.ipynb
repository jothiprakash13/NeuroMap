# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import gc
import os

# CLEANUP

gc.collect()
tf.keras.backend.clear_session()

# CONFIG

TRAIN_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'
TEST_PATH  = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing'
IMG_SIZE   = (224, 224)  
BATCH_SIZE = 32
AUTOTUNE   = tf.data.AUTOTUNE
all_images = []
all_labels = []
class_names = sorted(os.listdir(TRAIN_PATH))
NUM_CLASSES = len(class_names)
print("Classes:", class_names)

for label_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(TRAIN_PATH, class_name)
    for fname in os.listdir(class_dir):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            all_images.append(os.path.join(class_dir, fname))
            all_labels.append(label_idx)


# TRAIN / VALIDATION SPLIT

train_paths, val_paths, train_labels, val_labels = train_test_split(
    all_images, all_labels,
    test_size=0.15,
    stratify=all_labels,
    random_state=42
)
print(f"Train: {len(train_paths)}")
print(f"Validation: {len(val_paths)}")
print("Validation Distribution:",
      {class_names[k]
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)
class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)


# IMAGE LOADING 

def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

# AUGMENTATION 

_aug_rotate = tf.keras.layers.RandomRotation(0.10, fill_mode='reflect')
_aug_zoom   = tf.keras.layers.RandomZoom(0.10,   fill_mode='reflect')

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    img = tf.image.random_brightness(img, 0.15)
    img = tf.image.random_contrast(img, 0.85, 1.15)
    img = tf.image.random_saturation(img, 0.85, 1.15)

    img = tf.expand_dims(img, 0)          
    img = _aug_rotate(img, training=True)
    img = _aug_zoom(img,   training=True)
    img = tf.squeeze(img, 0)              

    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, label

# TRAIN DATASET

train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_ds = train_ds.shuffle(len(train_paths), seed=42, reshuffle_each_iteration=True)
train_ds = train_ds.map(load_image, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.cache()                        
train_ds = train_ds.map(augment, num_parallel_calls=AUTOTUNE)  
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(AUTOTUNE)


# VALIDATION DATASET

val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
val_ds = val_ds.map(load_image, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.cache()
val_ds = val_ds.batch(BATCH_SIZE)
val_ds = val_ds.prefetch(AUTOTUNE)

# TEST DATASET

test_images, test_labels = [], []
for label_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(TEST_PATH, class_name)
    for fname in os.listdir(class_dir):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            test_images.append(os.path.join(class_dir, fname))
            test_labels.append(label_idx)

test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_ds = test_ds.map(load_image, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(AUTOTUNE)

# MODEL 


def residual_block(x, filters, stride=1):
    """
    Pre-activation residual block (BN → ReLU → Conv).
    Shortcut uses 1×1 conv when dims change.
    """
    shortcut = x

    # Main path
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(
        filters, 3, strides=stride, padding='same',
        use_bias=False, kernel_regularizer=l2(1e-4)
    )(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(
        filters, 3, padding='same',
        use_bias=False, kernel_regularizer=l2(1e-4)
    )(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(
            filters, 1, strides=stride, padding='same',
            use_bias=False, kernel_regularizer=l2(1e-4)
        )(shortcut)

    x = layers.Add()([x, shortcut])
    return x


def build_model():
    inputs = layers.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

    # ── Stem ──────────────────────────────────────────
    x = layers.Conv2D(
        32, 7, strides=2, padding='same',
        use_bias=False, kernel_regularizer=l2(1e-4)
    )(inputs)                                          # 112×112×32
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)  # 56×56×32

    # ── Stage 1: 56×56 ────────────────────────────────
    x = residual_block(x, 64)
    x = residual_block(x, 64)

    # ── Stage 2: 28×28 ────────────────────────────────
    x = residual_block(x, 128, stride=2)
    x = residual_block(x, 128)

    # ── Stage 3: 14×14 ────────────────────────────────
    x = residual_block(x, 256, stride=2)
    x = residual_block(x, 256)

    # ── Stage 4: 7×7 ──────────────────────────────────
    x = residual_block(x, 512, stride=2)
    x = residual_block(x, 512)

    # ── Head ──────────────────────────────────────────
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.40)(x)                     
    x = layers.Dense(
        256, activation='relu',
        kernel_regularizer=l2(1e-4)
    )(x)
    x = layers.Dropout(0.30)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

    return models.Model(inputs, outputs)

# COMPILE
model = build_model()
model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=3e-4,
        weight_decay=1e-4
    ),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    ),
    metrics=['accuracy']
)

def to_one_hot(img, label):
    return img, tf.one_hot(label, NUM_CLASSES)

train_ds_oh = train_ds.map(to_one_hot)
val_ds_oh   = val_ds.map(to_one_hot)
test_ds_oh  = test_ds.map(to_one_hot)

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=3e-4,
        weight_decay=1e-4
    ),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

model.summary()

# CALLBACKS

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,            
        min_lr=1e-6,
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        '/kaggle/working/best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# TRAIN

history = model.fit(
    train_ds_oh,
    validation_data=val_ds_oh,
    epochs=60,                  
    callbacks=callbacks,
    class_weight=class_weights
)

# EVALUATE

loss, acc = model.evaluate(test_ds_oh)
print(f"\nTest Accuracy : {round(acc, 4)}")
print(f"Test Loss     : {round(loss, 4)}")

# TRAINING CURVES

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['accuracy'],     label='Train Acc')
axes[0].plot(history.history['val_accuracy'], label='Val Acc')
axes[0].set_title('Accuracy'); axes[0].legend(); axes[0].grid(True)

axes[1].plot(history.history['loss'],     label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Val Loss')
axes[1].set_title('Loss'); axes[1].legend(); axes[1].grid(True)

plt.tight_layout()
plt.savefig('/kaggle/working/training_curves.png', dpi=150)
plt.show()

# SAVE

model.save('/kaggle/working/best_model.keras')
print("Model saved successfully.")
# Out:
# 2026-06-12 20:07:37.843004: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781294858.269721      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781294858.384192      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781294859.434873      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781294859.434915      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781294859.434918      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781294859.434921      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# Train: 4760
# Validation: 840
# Validation Distribution: {'glioma': 210, 'meningioma': 210, 'notumor': 210, 'pituitary': 210}
# Class Weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0)}
# I0000 00:00:1781294881.928509      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1781294881.931639      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      4,704 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 112, 112,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 56, 56,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        128 │ max_pooling2d[0]… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 56, 56,    │     18,432 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 56, 56,    │     36,864 │ activation_2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 56, 56,    │      2,048 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ conv2d_2[0][0],   │
# │                     │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ add[0][0]         │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     36,864 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,864 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 56, 56,    │          0 │ conv2d_5[0][0],   │
# │                     │ 64)               │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ add_1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │     73,728 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │    147,456 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │      8,192 │ add_1[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 28, 28,    │          0 │ conv2d_7[0][0],   │
# │                     │ 128)              │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ add_2[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │    147,456 │ activation_7[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    147,456 │ activation_8[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 28, 28,    │          0 │ conv2d_10[0][0],  │
# │                     │ 128)              │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ add_3[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 14, 14,    │    294,912 │ activation_9[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 14, 14,    │    589,824 │ activation_10[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 14, 14,    │     32,768 │ add_3[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 14, 14,    │          0 │ conv2d_12[0][0],  │
# │                     │ 256)              │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ add_4[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 14, 14,    │    589,824 │ activation_11[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 14, 14,    │    589,824 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 14, 14,    │          0 │ conv2d_15[0][0],  │
# │                     │ 256)              │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ add_5[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 7, 7, 512) │  1,179,648 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 7, 7, 512) │    131,072 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 7, 7, 512) │          0 │ conv2d_17[0][0],  │
# │                     │                   │            │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ add_6[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 7, 7, 512) │          0 │ conv2d_20[0][0],  │
# │                     │                   │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ add_7[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ activation_17[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    131,328 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4)         │      1,028 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,293,796 (43.08 MB)
#  Trainable params: 11,285,988 (43.05 MB)
#  Non-trainable params: 7,808 (30.50 KB)
# Epoch 1/60
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781294896.536973      70 service.cc:152] XLA service 0x7a5a8c003950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781294896.537010      70 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1781294896.537111      70 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1781294899.170453      70 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/149 ━━━━━━━━━━━━━━━━━━━━ 1:10:49 29s/step - accuracy: 0.4375 - loss: 1.8208
# I0000 00:00:1781294914.303259      70 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5313 - loss: 1.6437
# Epoch 1: val_accuracy improved from None to 0.25000, saving model to /kaggle/working/best_model.keras
#
# Epoch 1: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 88s 403ms/step - accuracy: 0.5887 - loss: 1.5358 - val_accuracy: 0.2500 - val_loss: 3.0668 - learning_rate: 3.0000e-04
# Epoch 2/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6888 - loss: 1.3762
# Epoch 2: val_accuracy improved from 0.25000 to 0.32262, saving model to /kaggle/working/best_model.keras
#
# Epoch 2: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.7059 - loss: 1.3360 - val_accuracy: 0.3226 - val_loss: 2.3075 - learning_rate: 3.0000e-04
# Epoch 3/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7588 - loss: 1.2417
# Epoch 3: val_accuracy improved from 0.32262 to 0.64405, saving model to /kaggle/working/best_model.keras
#
# Epoch 3: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 214ms/step - accuracy: 0.7670 - loss: 1.2247 - val_accuracy: 0.6440 - val_loss: 1.4090 - learning_rate: 3.0000e-04
# Epoch 4/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7922 - loss: 1.1525
# Epoch 4: val_accuracy did not improve from 0.64405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.8002 - loss: 1.1289 - val_accuracy: 0.5440 - val_loss: 1.7224 - learning_rate: 3.0000e-04
# Epoch 5/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8018 - loss: 1.1054
# Epoch 5: val_accuracy improved from 0.64405 to 0.81786, saving model to /kaggle/working/best_model.keras
#
# Epoch 5: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 215ms/step - accuracy: 0.8206 - loss: 1.0780 - val_accuracy: 0.8179 - val_loss: 1.0675 - learning_rate: 3.0000e-04
# Epoch 6/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8227 - loss: 1.0467
# Epoch 6: val_accuracy did not improve from 0.81786
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.8351 - loss: 1.0276 - val_accuracy: 0.5631 - val_loss: 1.5685 - learning_rate: 3.0000e-04
# Epoch 7/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8384 - loss: 1.0077
# Epoch 7: val_accuracy improved from 0.81786 to 0.86429, saving model to /kaggle/working/best_model.keras
#
# Epoch 7: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 216ms/step - accuracy: 0.8479 - loss: 0.9882 - val_accuracy: 0.8643 - val_loss: 0.9528 - learning_rate: 3.0000e-04
# Epoch 8/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8645 - loss: 0.9543
# Epoch 8: val_accuracy did not improve from 0.86429
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.8729 - loss: 0.9293 - val_accuracy: 0.7833 - val_loss: 1.0785 - learning_rate: 3.0000e-04
# Epoch 9/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8679 - loss: 0.9218
# Epoch 9: val_accuracy did not improve from 0.86429
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 213ms/step - accuracy: 0.8807 - loss: 0.9002 - val_accuracy: 0.8583 - val_loss: 0.9179 - learning_rate: 3.0000e-04
# Epoch 10/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8820 - loss: 0.8816
# Epoch 10: val_accuracy did not improve from 0.86429
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.8847 - loss: 0.8704 - val_accuracy: 0.8560 - val_loss: 0.9005 - learning_rate: 3.0000e-04
# Epoch 11/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8715 - loss: 0.8667
# Epoch 11: val_accuracy did not improve from 0.86429
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 213ms/step - accuracy: 0.8861 - loss: 0.8414 - val_accuracy: 0.8083 - val_loss: 0.9564 - learning_rate: 3.0000e-04
# Epoch 12/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8932 - loss: 0.8360
# Epoch 12: val_accuracy did not improve from 0.86429
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.8983 - loss: 0.8208 - val_accuracy: 0.7548 - val_loss: 1.0751 - learning_rate: 3.0000e-04
# Epoch 13/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8978 - loss: 0.8022
# Epoch 13: val_accuracy improved from 0.86429 to 0.87262, saving model to /kaggle/working/best_model.keras
#
# Epoch 13: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 216ms/step - accuracy: 0.9000 - loss: 0.7993 - val_accuracy: 0.8726 - val_loss: 0.8636 - learning_rate: 3.0000e-04
# Epoch 14/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9019 - loss: 0.7949
# Epoch 14: val_accuracy did not improve from 0.87262
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 209ms/step - accuracy: 0.9059 - loss: 0.7835 - val_accuracy: 0.8500 - val_loss: 0.8962 - learning_rate: 3.0000e-04
# Epoch 15/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9039 - loss: 0.7763
# Epoch 15: val_accuracy did not improve from 0.87262
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 213ms/step - accuracy: 0.9111 - loss: 0.7661 - val_accuracy: 0.7881 - val_loss: 0.9741 - learning_rate: 3.0000e-04
# Epoch 16/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8992 - loss: 0.7779
# Epoch 16: val_accuracy did not improve from 0.87262
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9076 - loss: 0.7582 - val_accuracy: 0.6214 - val_loss: 1.2804 - learning_rate: 3.0000e-04
# Epoch 17/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9193 - loss: 0.7389
# Epoch 17: val_accuracy improved from 0.87262 to 0.92738, saving model to /kaggle/working/best_model.keras
#
# Epoch 17: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 217ms/step - accuracy: 0.9202 - loss: 0.7324 - val_accuracy: 0.9274 - val_loss: 0.7136 - learning_rate: 3.0000e-04
# Epoch 18/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9170 - loss: 0.7314
# Epoch 18: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9235 - loss: 0.7178 - val_accuracy: 0.7988 - val_loss: 0.9745 - learning_rate: 3.0000e-04
# Epoch 19/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9097 - loss: 0.7383
# Epoch 19: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9172 - loss: 0.7186 - val_accuracy: 0.8798 - val_loss: 0.8046 - learning_rate: 3.0000e-04
# Epoch 20/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9237 - loss: 0.7135
# Epoch 20: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9263 - loss: 0.7056 - val_accuracy: 0.9060 - val_loss: 0.7172 - learning_rate: 3.0000e-04
# Epoch 21/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9182 - loss: 0.7012
# Epoch 21: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9242 - loss: 0.6951 - val_accuracy: 0.9202 - val_loss: 0.6983 - learning_rate: 3.0000e-04
# Epoch 22/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9204 - loss: 0.6964
# Epoch 22: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9256 - loss: 0.6895 - val_accuracy: 0.8774 - val_loss: 0.7741 - learning_rate: 3.0000e-04
# Epoch 23/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9262 - loss: 0.6855
# Epoch 23: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9294 - loss: 0.6770 - val_accuracy: 0.9202 - val_loss: 0.7051 - learning_rate: 3.0000e-04
# Epoch 24/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9322 - loss: 0.6739
# Epoch 24: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 209ms/step - accuracy: 0.9380 - loss: 0.6645 - val_accuracy: 0.8607 - val_loss: 0.7808 - learning_rate: 3.0000e-04
# Epoch 25/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9278 - loss: 0.6711
# Epoch 25: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9347 - loss: 0.6653 - val_accuracy: 0.8440 - val_loss: 0.8084 - learning_rate: 3.0000e-04
# Epoch 26/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9332 - loss: 0.6692
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 26: val_accuracy did not improve from 0.92738
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9384 - loss: 0.6557 - val_accuracy: 0.9119 - val_loss: 0.7029 - learning_rate: 3.0000e-04
# Epoch 27/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9380 - loss: 0.6512
# Epoch 27: val_accuracy improved from 0.92738 to 0.95595, saving model to /kaggle/working/best_model.keras
#
# Epoch 27: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 215ms/step - accuracy: 0.9494 - loss: 0.6307 - val_accuracy: 0.9560 - val_loss: 0.6112 - learning_rate: 1.5000e-04
# Epoch 28/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9502 - loss: 0.6230
# Epoch 28: val_accuracy did not improve from 0.95595
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9534 - loss: 0.6156 - val_accuracy: 0.9476 - val_loss: 0.6068 - learning_rate: 1.5000e-04
# Epoch 29/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9497 - loss: 0.6212
# Epoch 29: val_accuracy did not improve from 0.95595
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9559 - loss: 0.6093 - val_accuracy: 0.9298 - val_loss: 0.6387 - learning_rate: 1.5000e-04
# Epoch 30/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9587 - loss: 0.6027
# Epoch 30: val_accuracy improved from 0.95595 to 0.95714, saving model to /kaggle/working/best_model.keras
#
# Epoch 30: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 216ms/step - accuracy: 0.9586 - loss: 0.6017 - val_accuracy: 0.9571 - val_loss: 0.5948 - learning_rate: 1.5000e-04
# Epoch 31/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9565 - loss: 0.5978
# Epoch 31: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9584 - loss: 0.5953 - val_accuracy: 0.8821 - val_loss: 0.7236 - learning_rate: 1.5000e-04
# Epoch 32/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9608 - loss: 0.5932
# Epoch 32: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9609 - loss: 0.5942 - val_accuracy: 0.8833 - val_loss: 0.7273 - learning_rate: 1.5000e-04
# Epoch 33/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9586 - loss: 0.5956
# Epoch 33: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9624 - loss: 0.5884 - val_accuracy: 0.9560 - val_loss: 0.5991 - learning_rate: 1.5000e-04
# Epoch 34/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9608 - loss: 0.5910
# Epoch 34: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9643 - loss: 0.5833 - val_accuracy: 0.9536 - val_loss: 0.5940 - learning_rate: 1.5000e-04
# Epoch 35/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9564 - loss: 0.5861
# Epoch 35: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9595 - loss: 0.5878 - val_accuracy: 0.9369 - val_loss: 0.6147 - learning_rate: 1.5000e-04
# Epoch 36/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9623 - loss: 0.5870
# Epoch 36: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9674 - loss: 0.5764 - val_accuracy: 0.9488 - val_loss: 0.5945 - learning_rate: 1.5000e-04
# Epoch 37/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9661 - loss: 0.5696
# Epoch 37: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9651 - loss: 0.5699 - val_accuracy: 0.9298 - val_loss: 0.6219 - learning_rate: 1.5000e-04
# Epoch 38/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9619 - loss: 0.5809
# Epoch 38: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9634 - loss: 0.5762 - val_accuracy: 0.9107 - val_loss: 0.6760 - learning_rate: 1.5000e-04
# Epoch 39/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9594 - loss: 0.5790
# Epoch 39: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9616 - loss: 0.5724 - val_accuracy: 0.9560 - val_loss: 0.5801 - learning_rate: 1.5000e-04
# Epoch 40/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9643 - loss: 0.5711
# Epoch 40: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 210ms/step - accuracy: 0.9666 - loss: 0.5694 - val_accuracy: 0.9143 - val_loss: 0.6416 - learning_rate: 1.5000e-04
# Epoch 41/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9680 - loss: 0.5653
# Epoch 41: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9687 - loss: 0.5629 - val_accuracy: 0.8905 - val_loss: 0.6928 - learning_rate: 1.5000e-04
# Epoch 42/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9601 - loss: 0.5742
# Epoch 42: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 213ms/step - accuracy: 0.9630 - loss: 0.5696 - val_accuracy: 0.9250 - val_loss: 0.6441 - learning_rate: 1.5000e-04
# Epoch 43/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9647 - loss: 0.5665
# Epoch 43: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9685 - loss: 0.5617 - val_accuracy: 0.9476 - val_loss: 0.5903 - learning_rate: 1.5000e-04
# Epoch 44/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9632 - loss: 0.5653
# Epoch 44: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 44: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 211ms/step - accuracy: 0.9674 - loss: 0.5580 - val_accuracy: 0.7869 - val_loss: 0.9223 - learning_rate: 1.5000e-04
# Epoch 45/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9731 - loss: 0.5515
# Epoch 45: val_accuracy did not improve from 0.95714
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - accuracy: 0.9763 - loss: 0.5424 - val_accuracy: 0.9560 - val_loss: 0.5583 - learning_rate: 7.5000e-05
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 30.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9175 - loss: 0.7116
#
# Test Accuracy : 0.9175
# Test Loss     : 0.7116
# Model saved successfully.

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred_probs = model.predict(test_ds_oh)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for _, y in test_ds_oh], axis=0)

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('/kaggle/working/confusion_matrix.png', dpi=150)
plt.show()

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step
#               precision    recall  f1-score   support
#
#       glioma       0.97      0.80      0.87       400
#   meningioma       0.93      0.89      0.91       400
#      notumor       0.88      0.99      0.93       400
#    pituitary       0.91      0.99      0.95       400
#
#     accuracy                           0.92      1600
#    macro avg       0.92      0.92      0.92      1600
# weighted avg       0.92      0.92      0.92      1600

# %% [markdown]
# **F1 Score, Precision, Recall**

# %%
# F1 SCORE, PRECISION, RECALL

from sklearn.metrics import classification_report

y_pred_probs = model.predict(test_ds_oh)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for _, y in test_ds_oh], axis=0)

print("\n========= Classification Report =========")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
#
# ========= Classification Report =========
#               precision    recall  f1-score   support
#
#       glioma       0.97      0.80      0.87       400
#   meningioma       0.93      0.89      0.91       400
#      notumor       0.88      0.99      0.93       400
#    pituitary       0.91      0.99      0.95       400
#
#     accuracy                           0.92      1600
#    macro avg       0.92      0.92      0.92      1600
# weighted avg       0.92      0.92      0.92      1600
